# %% [markdown]
# # Final Project (MP1–MP5)
#
# **Ad Soyad:** Ömer Yiğit Kocabaş, Umut Kılavuz, Mert Emre Selek, Batuhan Baysal​

# %% [markdown]
# ## MP1 Problem ve Hipotez

# %% [markdown]
# 📄 [MP1](MP1.pdf)

# %% [markdown]
# ## MP2 Literatür Taraması

# %% [markdown]
# 📄 [MP2](MP2.pdf)

# %% [markdown]
# ## MP3 Veri Toplama

# %% [markdown]
# [MP3](MP3/)

# %% [markdown]
# ## MP4 Analiz ve Görselleştirme

# %% [markdown]
# 📄 [MP4](MP4.pdf)

# %% [markdown]
# ## MP5 Raporlama

# %% [markdown]
# 📄 [MP5](MP5.pdf)
