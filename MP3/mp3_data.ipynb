# %% [markdown]
# # MP3 - Veri Toplama ve Analiz
# Bu çalışma, yapay zekâ araçlarının öğrencilerin eleştirel düşünme becerileri üzerindeki etkisini incelemektedir.
# Veriler anket yöntemiyle toplanmıştır.

# %%
import pandas as pd

df = pd.read_csv("data_mp3_40_ornek.csv")
df.head()
# Out:
#    ogrenci_id cinsiyet  yas ai_kullanım_sıklığı   ai_araç_türü  \
# 0           1    Erkek   18               Düşük  Google Gemini
# 1           2    Erkek   20               Düşük        ChatGPT
# 2           3    Erkek   24              Yüksek        ChatGPT
# 3           4    Erkek   21               Düşük            Yok
# 4           5    Erkek   24              Yüksek         Claude
#
#    eleştirel_düşünme_puanı
# 0                       58
# 1                       65
# 2                       87
# 3                       55
# 4                       93
